# %% [markdown]
# # **Machine Learning in Python: Performing Principal Component Analysis (PCA)**

# %% [markdown]
# ## **1. Load the Iris data set using SKLEARN**
#
# .. _iris_dataset:  Iris plants dataset
#
# **Data Set Characteristics:**
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:         - sepal length in cm
#                                 - sepal width in cm
#                                 - petal length in cm
#                                 - petal width in cm
#               - class:           - Iris-Setosa
#                                  - Iris-Versicolour
#                                  - Iris-Virginica
#
# :Summary Statistics:      ============== ==== ==== ======= ===== ====================
# Min  Max   Mean    SD   Class Correlation     ============== ==== ==== ======= ===== ====================     sepal length:   4.3  7.9   5.84   0.83    0.7826     sepal width:    2.0  4.4   3.05   0.43   -0.4194     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)     ============== ==== ==== ======= ===== ====================
#
# :Missing Attribute Values: None     :Class Distribution: 33.3% for each of 3 classes.     :Creator: R.A. Fisher     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)'

# %% [markdown]
# ### Load library

# %%
from sklearn import datasets

# %% [markdown]
# ### Load dataset

# %%
iris = datasets.load_iris()

# %% [markdown]
# ### Input  features

# %%
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ### Output features

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ### Assigning Input (X) and Output (Y) variables
# Let's assign the 4 input variables to X and the output variable (class label) to Y

# %%
X = iris.data
Y = iris.target

# %% [markdown]
# ### Let's examine the data dimension

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %% [markdown]
# ---

# %% [markdown]
# ## **2. PCA analysis**

# %% [markdown]
# ### 2.1. Load library

# %%
from sklearn.preprocessing import scale # Data scaling
from sklearn import decomposition #PCA
import pandas as pd # pandas

# %% [markdown]
# ### 2.2. Data scaling

# %%
X = scale(X)

# %% [markdown]
# ### 2.3. Perform PCA analysis

# %% [markdown]
# Here we define the number of PC to use as 3

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(n_components=3)

# %% [markdown]
# #### 2.4. Compute and retrieve the **scores** values

# %%
scores = pca.transform(X)

# %%
scores_df = pd.DataFrame(scores, columns=['PC1', 'PC2', 'PC3'])
scores_df
# Out:
#           PC1       PC2       PC3
# 0   -2.264703  0.480027 -0.127706
# 1   -2.080961 -0.674134 -0.234609
# 2   -2.364229 -0.341908  0.044201
# 3   -2.299384 -0.597395  0.091290
# 4   -2.389842  0.646835  0.015738
# ..        ...       ...       ...
# 145  1.870503  0.386966  0.256274
# 146  1.564580 -0.896687 -0.026371
# 147  1.521170  0.269069  0.180178
# 148  1.372788  1.011254  0.933395
# 149  0.960656 -0.024332  0.528249
#
# [150 rows x 3 columns]

# %%
Y_label = []

for i in Y:
  if i == 0:
    Y_label.append('Setosa')
  elif i == 1:
    Y_label.append('Versicolor')
  else:
    Y_label.append('Virginica')

Species = pd.DataFrame(Y_label, columns=['Species'])

# %%
df_scores = pd.concat([scores_df, Species], axis=1)
df_scores.loc[df_scores['Species']=="Setosa"].head(5)
# Out:
#         PC1       PC2       PC3 Species
# 0 -2.264703  0.480027 -0.127706  Setosa
# 1 -2.080961 -0.674134 -0.234609  Setosa
# 2 -2.364229 -0.341908  0.044201  Setosa
# 3 -2.299384 -0.597395  0.091290  Setosa
# 4 -2.389842  0.646835  0.015738  Setosa

# %% [markdown]
# #### 2.5. Retrieve the **loadings** values

# %%
loadings = pca.components_.T
df_loadings = pd.DataFrame(loadings, columns=['PC1', 'PC2','PC3'], index=iris.feature_names)
df_loadings
# Out:
#                         PC1       PC2       PC3
# sepal length (cm)  0.521066  0.377418 -0.719566
# sepal width (cm)  -0.269347  0.923296  0.244382
# petal length (cm)  0.580413  0.024492  0.142126
# petal width (cm)   0.564857  0.066942  0.634273

# %% [markdown]
# #### 2.6. **Explained variance** for each PC

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.72962445, 0.22850762, 0.03668922])

# %% [markdown]
# ## **3. Scree Plot**

# %% [markdown]
# ### 3.1. Import library

# %%
import numpy as np
import plotly.express as px

# %% [markdown]
# ### 3.2. Preparing explained variance and cumulative variance

# %% [markdown]
# #### 3.2.1. Preparing the explained variance data

# %%
explained_variance
# Out:
# array([0.72962445, 0.22850762, 0.03668922])

# %%
explained_variance = np.insert(explained_variance, 0, 0)

# %% [markdown]
# #### 3.2.2. Preparing the cumulative variance data

# %%
cumulative_variance = np.cumsum(np.round(explained_variance, decimals=3))

# %% [markdown]
# #### 3.2.3. Combining the dataframe

# %%
pc_df = pd.DataFrame(['','PC1', 'PC2', 'PC3'], columns=['PC'])
explained_variance_df = pd.DataFrame(explained_variance, columns=['Explained Variance'])
cumulative_variance_df = pd.DataFrame(cumulative_variance, columns=['Cumulative Variance'])

# %%
df_explained_variance = pd.concat([pc_df, explained_variance_df, cumulative_variance_df], axis=1)
df_explained_variance
# Out:
#     PC  Explained Variance  Cumulative Variance
# 0                 0.000000                0.000
# 1  PC1            0.729624                0.730
# 2  PC2            0.228508                0.959
# 3  PC3            0.036689                0.996

# %% [markdown]
# #### 3.2.4. Making the scree plot

# %% [markdown]
# ##### 3.2.4.1. Explained Variance

# %%
# https://plotly.com/python/bar-charts/

fig = px.bar(df_explained_variance, 
             x='PC', y='Explained Variance',
             text='Explained Variance',
             width=800)

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')
fig.show()
# Out:
# <div>                            <div id="11e96e26-ae11-423e-a8d6-12d3ee3e0c7c" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11e96e26-ae11-423e-a8d6-12d3ee3e0c7c")) {                    Plotly.newPlot(                        "11e96e26-ae11-423e-a8d6-12d3ee3e0c7c",                        [{"alignmentgroup":"True","hovertemplate":"PC=%{x}<br>Explained Variance=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.0,0.7296244541329986,0.22850761786701776,0.03668921889282877],"textposition":"outside","texttemplate":"%{text:.3f}","type":"bar","x":["","PC1","PC2","PC3"],"xaxis":"x","y":[0.0,0.7296244541329986,0.22850761786701776,0.03668921889282877],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewid ...

# %% [markdown]
# ##### 3.2.4.2. Explained Variance + Cumulative Variance

# %%
# https://plotly.com/python/creating-and-updating-figures/

import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Cumulative Variance'],
        marker=dict(size=15, color="LightSeaGreen")
    ))

fig.add_trace(
    go.Bar(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Explained Variance'],
        marker=dict(color="RoyalBlue")
    ))

fig.show()
# Out:
# <div>                            <div id="e9ee8ce4-ea0f-491c-88f2-225423e3fe6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9ee8ce4-ea0f-491c-88f2-225423e3fe6b")) {                    Plotly.newPlot(                        "e9ee8ce4-ea0f-491c-88f2-225423e3fe6b",                        [{"marker":{"color":"LightSeaGreen","size":15},"type":"scatter","x":["","PC1","PC2","PC3"],"y":[0.0,0.73,0.959,0.996]},{"marker":{"color":"RoyalBlue"},"type":"bar","x":["","PC1","PC2","PC3"],"y":[0.0,0.7296244541329986,0.22850761786701776,0.03668921889282877]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d" ...
#
# var gd = document.getElementById('e9ee8ce4-ea0f-491c-88f2-225423e3fe6b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window

# %% [markdown]
# ##### 3.2.4.3. Explained Variance + Cumulative Variance (Separate Plot)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2)

fig.add_trace(
    go.Scatter(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Cumulative Variance'],
        marker=dict(size=15, color="LightSeaGreen")
    ), row=1, col=1
    )

fig.add_trace(
    go.Bar(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Explained Variance'],
        marker=dict(color="RoyalBlue"),
    ), row=1, col=2
    )

fig.show()
# Out:
# <div>                            <div id="f77a736d-04c3-4fff-8625-94f56fe699b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f77a736d-04c3-4fff-8625-94f56fe699b3")) {                    Plotly.newPlot(                        "f77a736d-04c3-4fff-8625-94f56fe699b3",                        [{"marker":{"color":"LightSeaGreen","size":15},"type":"scatter","x":["","PC1","PC2","PC3"],"xaxis":"x","y":[0.0,0.73,0.959,0.996],"yaxis":"y"},{"marker":{"color":"RoyalBlue"},"type":"bar","x":["","PC1","PC2","PC3"],"xaxis":"x2","y":[0.0,0.7296244541329986,0.22850761786701776,0.03668921889282877],"yaxis":"y2"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar" ...

# %% [markdown]
# ## **4. Scores Plot**
#
# Source: https://plotly.com/python/3d-scatter-plots/

# %% [markdown]
# ### 4.1. Load library
# [API Documentation](https://plotly.com/python-api-reference/plotly.express.html) for *plotly.express* package

# %%
import plotly.express as px

# %% [markdown]
# ### 4.2. Basic 3D Scatter Plot

# %%
fig = px.scatter_3d(df_scores, x='PC1', y='PC2', z='PC3',
              color='Species')

fig.show()
# Out:
# <div>                            <div id="3b07b594-0ef5-4a0d-b7eb-a8ea2afd2d0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b07b594-0ef5-4a0d-b7eb-a8ea2afd2d0e")) {                    Plotly.newPlot(                        "3b07b594-0ef5-4a0d-b7eb-a8ea2afd2d0e",                        [{"hovertemplate":"Species=Setosa<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"Setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Setosa","scene":"scene","showlegend":true,"type":"scatter3d","x":[-2.264702808807587,-2.080961151965766,-2.3642290538902992,-2.2993842170427063,-2.389842166313843,-2.0756309481765105,-2.4440288351341506,-2.2328471588720133,-2.33464047790762,-2.184328174933941,-2.166310100701321,-2.3261308664426967,-2.218450898822408,-2.6331006957652265,-2.1987406032666885,-2.2622145316010194,-2.2075876958245906,-2.1903495091922975,-1.8985719958028404,-2.3433690530749915,-1.9143229960825665,-2.207012843194797,-2.77434470292733,-1.8186695286958479,-2.227163305706637,-1.9518463309003744,-2.051151372729414,-2.1685771746542146,-2.13956345130133,-2.265261493154239,-2.140122135647983,-1.831594770676027,-2.6149479358589325,-2.446177391696513,-2.109974875318651,-2.2078088990782643,-2.0451462067542,-2.5273319131704843,-2.4296325750845447,-2.169710711630662,-2.286475143345669,-1.8581224563735705,-2.553638395614354,-1.964447683763739,-2.1370590058116212,-2.0697442995918287,-2.3847331657782607,-2.394376314219631,-2.229446547942673,-2.2038334355191287],"y":[0.48002659652098933,-0.6741335566053522,-0.34190802388467567,-0.5973945076746748,0.646835382902027,1.4891775233211664,0.04764419763001472,0.22314807268959205,-1.1153276754616654,-0.4690135614023752,1.0436906530538594,0.13307833523923204,-0.7286761653165701,-0.961506729170162,1.8600571132939303,2.686284485110591,1.483609363155572,0.4888383164863277,1.4050187944665486,1.1278493819084758,0.4088557077559063,0.9241214267468981,0.4583436677529158,0.08555852628736633,0.1372544553634277,-0.6256185877766761,0.24216355266166734,0.5271495253082674,0.313217810139952,-0.33773190376048,-0.5045406901415177,0.42369506760378595,1.793575856104428,2.1507278773929235,-0.4602018414370368,-0.20610739768843656,0.6615581114631081,0.5922927741908095,-0.904180040376147,0.2688789614354711,0.44171538769905017,-2.337415157553347,-0.4791006901223134,0.47232666771926096,1.1422292620394086,-0.7110527253858934,1.120429701984536,-0.3862468725891566,0.9979597643079802,0.00921635752127653],"z":[-0.1277060223001527,-0.2346088539845681,0.04420148483874353,0.09129010632068191,0.01573819567625845,0.02696829443978177,0.33547040114311377,-0.08869549794772658,0.1450768636369998,-0.25376556730000677,-0.26868110221613506,0.0937592443811115,-0.230911237206603,0.18079608440317907,-0.47290099787307727,0.03052660926551054,-0.005344094078264305,-0.044215316478454225,-0.374343274557655,0.13263046678130186,-0.4212925940873567,0.15986527722625254,0.3321790975568659,0.03448859579998109,0.117993535769646,-0.3056409823252081,0.08636401082518208,-0.20681624777030483,-0.27115024027656465,0.06843577622727803,-0.07500844174913324,-0.27046737670298254,0.04722841866848593,-0.08266804506156811,-0.17027486147830828,-0.22544158008975745,-0.4845374098283175,0.01943581245422299,0.19325466188423657,-0.17588382054738938,0.034894908991697116,-0.20423422253096568,0.30576645263773305,0.3096013178453274,0.24843356112104664,-0.06392982556320603,0.05721785808911495,0.1394679045679187,-0.18149277961647137,-0.1530294904539865]},{"hovertemplate":"Species=Versicolor<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"Versicolor","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Versicolor","scene":"scene","showlegend":true,"type":"scatter3d","x":[1 ...

# %% [markdown]
# ### 4.3. Customized 3D Scatter Plot

# %%
fig = px.scatter_3d(df_scores, x='PC1', y='PC2', z='PC3',
              color='Species',
              symbol='Species',
              opacity=0.5)

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))

# https://plotly.com/python/templates/
#fig.update_layout(template='plotly_white') # "plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"
# Out:
# <div>                            <div id="ff46efda-507d-4abf-9db4-272ebc5eead3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff46efda-507d-4abf-9db4-272ebc5eead3")) {                    Plotly.newPlot(                        "ff46efda-507d-4abf-9db4-272ebc5eead3",                        [{"hovertemplate":"Species=Setosa<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"Setosa","marker":{"color":"#636efa","opacity":0.5,"symbol":"circle"},"mode":"markers","name":"Setosa","scene":"scene","showlegend":true,"type":"scatter3d","x":[-2.264702808807587,-2.080961151965766,-2.3642290538902992,-2.2993842170427063,-2.389842166313843,-2.0756309481765105,-2.4440288351341506,-2.2328471588720133,-2.33464047790762,-2.184328174933941,-2.166310100701321,-2.3261308664426967,-2.218450898822408,-2.6331006957652265,-2.1987406032666885,-2.2622145316010194,-2.2075876958245906,-2.1903495091922975,-1.8985719958028404,-2.3433690530749915,-1.9143229960825665,-2.207012843194797,-2.77434470292733,-1.8186695286958479,-2.227163305706637,-1.9518463309003744,-2.051151372729414,-2.1685771746542146,-2.13956345130133,-2.265261493154239,-2.140122135647983,-1.831594770676027,-2.6149479358589325,-2.446177391696513,-2.109974875318651,-2.2078088990782643,-2.0451462067542,-2.5273319131704843,-2.4296325750845447,-2.169710711630662,-2.286475143345669,-1.8581224563735705,-2.553638395614354,-1.964447683763739,-2.1370590058116212,-2.0697442995918287,-2.3847331657782607,-2.394376314219631,-2.229446547942673,-2.2038334355191287],"y":[0.48002659652098933,-0.6741335566053522,-0.34190802388467567,-0.5973945076746748,0.646835382902027,1.4891775233211664,0.04764419763001472,0.22314807268959205,-1.1153276754616654,-0.4690135614023752,1.0436906530538594,0.13307833523923204,-0.7286761653165701,-0.961506729170162,1.8600571132939303,2.686284485110591,1.483609363155572,0.4888383164863277,1.4050187944665486,1.1278493819084758,0.4088557077559063,0.9241214267468981,0.4583436677529158,0.08555852628736633,0.1372544553634277,-0.6256185877766761,0.24216355266166734,0.5271495253082674,0.313217810139952,-0.33773190376048,-0.5045406901415177,0.42369506760378595,1.793575856104428,2.1507278773929235,-0.4602018414370368,-0.20610739768843656,0.6615581114631081,0.5922927741908095,-0.904180040376147,0.2688789614354711,0.44171538769905017,-2.337415157553347,-0.4791006901223134,0.47232666771926096,1.1422292620394086,-0.7110527253858934,1.120429701984536,-0.3862468725891566,0.9979597643079802,0.00921635752127653],"z":[-0.1277060223001527,-0.2346088539845681,0.04420148483874353,0.09129010632068191,0.01573819567625845,0.02696829443978177,0.33547040114311377,-0.08869549794772658,0.1450768636369998,-0.25376556730000677,-0.26868110221613506,0.0937592443811115,-0.230911237206603,0.18079608440317907,-0.47290099787307727,0.03052660926551054,-0.005344094078264305,-0.044215316478454225,-0.374343274557655,0.13263046678130186,-0.4212925940873567,0.15986527722625254,0.3321790975568659,0.03448859579998109,0.117993535769646,-0.3056409823252081,0.08636401082518208,-0.20681624777030483,-0.27115024027656465,0.06843577622727803,-0.07500844174913324,-0.27046737670298254,0.04722841866848593,-0.08266804506156811,-0.17027486147830828,-0.22544158008975745,-0.4845374098283175,0.01943581245422299,0.19325466188423657,-0.17588382054738938,0.034894908991697116,-0.20423422253096568,0.30576645263773305,0.3096013178453274,0.24843356112104664,-0.06392982556320603,0.05721785808911495,0.1394679045679187,-0.18149277961647137,-0.1530294904539865]},{"hovertemplate":"Species=Versicolor<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"Versicolor","marker":{"color":"#EF553B","opacity":0.5,"symbol":"diamond"},"mode":"markers","name":"Versicolor","scene":"scene","showlegend":t ...

# %% [markdown]
# ## **5. Loadings Plot**

# %%
loadings_label = df_loadings.index
# loadings_label = df_loadings.index.str.strip(' (cm)')

fig = px.scatter_3d(df_loadings, x='PC1', y='PC2', z='PC3',
                    text = loadings_label)

fig.show()
# Out:
# <div>                            <div id="01182176-40ab-44f7-b2e9-806d467800de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01182176-40ab-44f7-b2e9-806d467800de")) {                    Plotly.newPlot(                        "01182176-40ab-44f7-b2e9-806d467800de",                        [{"hovertemplate":"PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<br>index=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["sepal length (cm)","sepal width (cm)","petal length (cm)","petal width (cm)"],"type":"scatter3d","x":[0.5210659146701195,-0.2693474425059428,0.5804130957962944,0.5648565357793611],"y":[0.37741761556456704,0.9232956595407146,0.02449160908558634,0.06694198696805842],"z":[-0.7195663527008167,0.24438177951439932,0.14212636933390346,0.634272737110923]}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"scene":{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"xaxis":{"title":{"text":"PC1"}},"yaxis":{"title":{"text":"PC2"}},"zaxis":{"title":{"text":"PC3"}}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777 ...

# %% [markdown]
# ---
